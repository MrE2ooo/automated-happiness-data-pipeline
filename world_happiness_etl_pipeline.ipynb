# %% [markdown]
# <a href="https://colab.research.google.com/github/MrE2ooo/automated-happiness-data-pipeline/blob/main/world_happiness_etl_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install Prefect and other dependencies
# !pip install -U prefect pandas kagglehub supabase nest_asyncio

# 2. Login with your API KEY
# !prefect cloud login -k Login with your API KEY

# 3. Force the workspace to sync (run this if the dashboard still shows 0)
# !prefect cloud workspace set
# Out:
# Requirement already satisfied: prefect in /usr/local/lib/python3.12/dist-packages (3.6.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting pandas
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Collecting kagglehub
#   Downloading kagglehub-0.4.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: supabase in /usr/local/lib/python3.12/dist-packages (2.27.1)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Requirement already satisfied: aiosqlite<1.0.0,>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.22.0)
# Requirement already satisfied: alembic<2.0.0,>=1.7.5 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.17.2)
# Requirement already satisfied: anyio<5.0.0,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (4.12.0)
# Requirement already satisfied: apprise<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.9.6)
# Requirement already satisfied: asgi-lifespan<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (2.1.0)
# Requirement already satisfied: asyncpg<1.0.0,>=0.23 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.31.0)
# Requirement already satisfied: cachetools<7.0,>=5.3 in /usr/local/lib/python3.12/dist-packages (from prefect) (6.2.4)
# Requirement already satisfied: click<9,>=8.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (8.3.1)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (3.1.2)
# Requirement already satisfied: coolname<3.0.0,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from prefect) (2.2.0)
# Requirement already satisfied: cryptography>=36.0.1 in /usr/local/lib/python3.12/dist-packages (from prefect) (43.0.3)
# Requirement already satisfied: dateparser<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.2.2)
# Requirement already satisfied: docker<8.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (7.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.3.1)
# Requirement already satisfied: fastapi<1.0.0,>=0.111.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.123.10)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (2025.3.0)
# Requirement already satisfied: graphviz>=0.20.1 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.21)
# Requirement already satisfied: griffe<2.0.0,>=0.49.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.15.0)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.0.9)
# Requirement already satisfied: httpx!=0.23.2,>=0.23 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]!=0.23.2,>=0.23->prefect) (0.28.1)
# Requirement already satisfied: humanize<5.0.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (4.14.0)
# Requirement already satisfied: jinja2-humanize-extension>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.4.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from prefect) (3.1.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.32 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.33)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (4.25.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.39.1)
# Requirement already satisfied: orjson<4.0,>=3.7 in /usr/local/lib/python3.12/dist-packages (from prefect) (3.11.5)
# Requirement already satisfied: packaging<25.1,>=21.3 in /usr/local/lib/python3.12/dist-packages (from prefect) (25.0)
# Requirement already satisfied: pathspec>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.0.3)
# Requirement already satisfied: pendulum<4,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (3.1.0)
# Requirement already satisfied: pluggy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.6.0)
# Requirement already satisfied: prometheus-client>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.23.1)
# Requirement already satisfied: pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from prefect) (2.12.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.12.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (2.41.4)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from prefect) (2.11.0)
# Requirement already satisfied: pydantic-settings!=2.9.0,<3.0.0,>2.2.1 in /usr/local/lib/python3.12/dist-packages (from prefect) (2.12.0)
# Requirement already satisfied: pydocket>=0.16.2 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.16.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from prefect) (2.9.0.post0)
# Requirement already satisfied: python-slugify<9.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (8.0.4)
# Requirement already satisfied: pytz<2026,>=2021.1 in /usr/local/lib/python3.12/dist-packages (from prefect) (2025.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from prefect) (6.0.3)
# Requirement already satisfied: readchar<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (4.2.1)
# Requirement already satisfied: rfc3339-validator<0.2.0,>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.1.4)
# Requirement already satisfied: rich<15.0,>=11.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (13.9.4)
# Requirement already satisfied: ruamel-yaml-clib>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.2.15)
# Requirement already satisfied: ruamel-yaml>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.19.1)
# Requirement already satisfied: semver>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from prefect) (3.0.4)
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (1.3.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy[asyncio]<3.0.0,>=2.0->prefect) (2.0.45)
# Requirement already satisfied: toml>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.10.2)
# Requirement already satisfied: typer<0.21.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.20.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (4.15.0)
# Requirement already satisfied: uvicorn!=0.29.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from prefect) (0.38.0)
# Requirement already satisfied: websockets<16.0,>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from prefect) (15.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: realtime==2.27.1 in /usr/local/lib/python3.12/dist-packages (from supabase) (2.27.1)
# Requirement already satisfied: supabase-functions==2.27.1 in /usr/local/lib/python3.12/dist-packages (from supabase) (2.27.1)
# Requirement already satisfied: storage3==2.27.1 in /usr/local/lib/python3.12/dist-packages (from supabase) (2.27.1)
# Requirement already satisfied: supabase-auth==2.27.1 in /usr/local/lib/python3.12/dist-packages (from supabase) (2.27.1)
# Requirement already satisfied: postgrest==2.27.1 in /usr/local/lib/python3.12/dist-packages (from supabase) (2.27.1)
# Requirement already satisfied: yarl>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from supabase) (1.22.0)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from postgrest==2.27.1->supabase) (2.1.0)
# Requirement already satisfied: pyiceberg>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from storage3==2.27.1->supabase) (0.10.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.27.1->supabase) (2.10.1)
# Requirement already satisfied: strenum>=0.4.15 in /usr/local/lib/python3.12/dist-packages (from supabase-functions==2.27.1->supabase) (0.4.15)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic<2.0.0,>=1.7.5->prefect) (1.3.10)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.4.0->prefect) (3.11)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from apprise<2.0.0,>=1.1.0->prefect) (2.0.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from apprise<2.0.0,>=1.1.0->prefect) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from apprise<2.0.0,>=1.1.0->prefect) (2025.11.12)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.1->prefect) (2.0.0)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser<2.0.0,>=1.1.1->prefect) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser<2.0.0,>=1.1.1->prefect) (5.3.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker<8.0,>=4.0->prefect) (2.5.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0.0,>=0.111.0->prefect) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0.0,>=0.111.0->prefect) (0.0.4)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffe<2.0.0,>=0.49.0->prefect) (0.4.6)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore<2.0.0,>=1.0.5->prefect) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]!=0.23.2,>=0.23->prefect) (4.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.6->prefect) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.32->prefect) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (0.30.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.5)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<2.0.0,>=1.27.0->prefect) (8.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1->prefect) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1->prefect) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings!=2.9.0,<3.0.0,>2.2.1->prefect) (1.2.1)
# Requirement already satisfied: fakeredis>=2.32.1 in /usr/local/lib/python3.12/dist-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.16.2->prefect) (2.33.0)
# Requirement already satisfied: opentelemetry-exporter-prometheus>=0.60b0 in /usr/local/lib/python3.12/dist-packages (from pydocket>=0.16.2->prefect) (0.60b1)
# Requirement already satisfied: opentelemetry-instrumentation>=0.60b0 in /usr/local/lib/python3.12/dist-packages (from pydocket>=0.16.2->prefect) (0.60b1)
# Requirement already satisfied: py-key-value-aio>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio[memory,redis]>=0.3.0->pydocket>=0.16.2->prefect) (0.3.0)
# Requirement already satisfied: python-json-logger>=2.0.7 in /usr/local/lib/python3.12/dist-packages (from pydocket>=0.16.2->prefect) (4.0.0)
# Requirement already satisfied: redis>=5 in /usr/local/lib/python3.12/dist-packages (from pydocket>=0.16.2->prefect) (7.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.2->prefect) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify<9.0,>=5.0->prefect) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0,>=11.0->prefect) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0,>=11.0->prefect) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=2.0->sqlalchemy[asyncio]<3.0.0,>=2.0->prefect) (3.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.21.0,>=0.16.0->prefect) (1.5.4)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.22.0->supabase) (6.7.0)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.22.0->supabase) (0.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.1->prefect) (2.23)
# Requirement already satisfied: sortedcontainers>=2 in /usr/local/lib/python3.12/dist-packages (from fakeredis>=2.32.1->fakeredis[lua]>=2.32.1->pydocket>=0.16.2->prefect) (2.4.0)
# Requirement already satisfied: lupa>=2.1 in /usr/local/lib/python3.12/dist-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.16.2->prefect) (2.6)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect) (4.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.27.0->prefect) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<15.0,>=11.0->prefect) (0.1.2)
# Requirement already satisfied: opentelemetry-sdk~=1.39.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-prometheus>=0.60b0->pydocket>=0.16.2->prefect) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation>=0.60b0->pydocket>=0.16.2->prefect) (0.60b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation>=0.60b0->pydocket>=0.16.2->prefect) (1.17.3)
# Requirement already satisfied: py-key-value-shared==0.3.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio>=0.3.0->py-key-value-aio[memory,redis]>=0.3.0->pydocket>=0.16.2->prefect) (0.3.0)
# Requirement already satisfied: beartype>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio>=0.3.0->py-key-value-aio[memory,redis]>=0.3.0->pydocket>=0.16.2->prefect) (0.22.9)
# Requirement already satisfied: mmh3<6.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.27.1->supabase) (5.2.0)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.27.1->supabase) (3.2.5)
# Requirement already satisfied: pyroaring<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.27.1->supabase) (1.0.3)
# Requirement already satisfied: strictyaml<2.0.0,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.27.1->supabase) (1.7.3)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from pyiceberg>=0.10.0->storage3==2.27.1->supabase) (9.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->apprise<2.0.0,>=1.1.0->prefect) (3.3.1)
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 92.8 MB/s eta 0:00:00
# Downloading kagglehub-0.4.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 3.9 MB/s eta 0:00:00
# Downloading kagglesdk-0.1.14-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: pandas, kagglesdk, kagglehub
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: kagglehub
#     Found existing installation: kagglehub 0.3.13
#     Uninstalling kagglehub-0.3.13:
#       Successfully uninstalled kagglehub-0.3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed kagglehub-0.4.0 kagglesdk-0.1.14 pandas-2.3.3
# It looks like you're already authenticated on this profile.
# ? Would you like to reauthenticate? [y/N]: y
# Authenticated with Prefect Cloud! Using workspace 'world-happiness/default'.
# ? Which workspace would you like to use? [Use arrows to move; enter to select]
# > world-happiness/default
# ? Which workspace would you like to use? [Use arrows to move; enter to select]
# > world-happiness/default
#   Go back to account selection
# Successfully set workspace to 'world-happiness/default' in profile 'ephemeral'.

# %%
import pandas as pd
import kagglehub
import nest_asyncio
from supabase import create_client
from prefect import flow, task

# Fix for Colab event loop
nest_asyncio.apply()

# --- CREDENTIALS ---
SUPABASE_URL = "SUPABASE_URL"
SUPABASE_KEY = "SUPABASE_KEY"
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

# --- TASKS ---
@task(name="Cleanup Old Data")
def clear_supabase_table():
    print("🧹 Clearing old data from Supabase...")
    supabase.table("world_happiness_2016").delete().neq("id", 0).execute()

@task(name="Extract 2016 Data")
def extract_2016():
    print("📥 Downloading dataset...")
    path = kagglehub.dataset_download("unsdsn/world-happiness")
    return pd.read_csv(f"{path}/2016.csv")

@task(name="Transform for Supabase")
def transform_2016(df):
    mapping = {
        'Country': 'country', 'Region': 'region', 'Happiness Rank': 'happiness_rank',
        'Happiness Score': 'happiness_score', 'Lower Confidence Interval': 'lower_confidence_interval',
        'Upper Confidence Interval': 'upper_confidence_interval', 'Economy (GDP per Capita)': 'economy_gdp_per_capita',
        'Family': 'family', 'Health (Life Expectancy)': 'health_life_expectancy',
        'Freedom': 'freedom', 'Trust (Government Corruption)': 'trust_government_corruption',
        'Generosity': 'generosity', 'Dystopia Residual': 'dystopia_residual'
    }
    df_renamed = df.rename(columns=mapping)
    return df_renamed[list(mapping.values())].to_dict(orient='records')

@task(name="Load to Supabase")
def load_to_supabase(data):
    print(f"🚀 Uploading {len(data)} rows...")
    return supabase.table("world_happiness_2016").insert(data).execute()

# --- THE FLOW ---
@flow(name="World Happiness 2016 Pipeline")
def happiness_flow():
    clear_supabase_table()
    raw_df = extract_2016()
    clean_json = transform_2016(raw_df)
    load_to_supabase(clean_json)

# %%
# Run this cell to "Force" a run into the dashboard
from prefect import flow

@flow(name="Emergency-Sync-Flow")
def sync_check():
    print("Syncing with Prefect Cloud...")

if __name__ == "__main__":
    sync_check() # This runs it locally but reports to the cloud
# Out:
# INFO:prefect.flow_runs:Beginning flow run 'flying-lobster' for flow 'Emergency-Sync-Flow'
# INFO:prefect.flow_runs:View at https://app.prefect.cloud/account/8cad1fd4-fdea-4780-978a-21f1f3b030a6/workspace/3fe9e30a-0912-4e18-a48a-7fcf239af3bd/runs/flow-run/06965135-8ec4-732b-8000-41decd01d607
# INFO:prefect.flow_runs:Finished in state Completed()
# Syncing with Prefect Cloud...

# %%
if __name__ == "__main__":
    print("🚀 Launching the World Happiness 2016 Pipeline...")

    # Running the flow directly ensures it appears in your 'Runs' tab right now
    happiness_flow()

    print("✅ Check your Prefect Dashboard 'Runs' tab for 'World Happiness 2016 Pipeline'!")
# Out:
# 🚀 Launching the World Happiness 2016 Pipeline...
# INFO:prefect.flow_runs:Beginning flow run 'nondescript-bulldog' for flow 'World Happiness 2016 Pipeline'
# INFO:prefect.flow_runs:View at https://app.prefect.cloud/account/8cad1fd4-fdea-4780-978a-21f1f3b030a6/workspace/3fe9e30a-0912-4e18-a48a-7fcf239af3bd/runs/flow-run/0696513e-e0ec-7dd1-8000-f9d489733ce8
# 🧹 Clearing old data from Supabase...
# INFO:prefect.task_runs:Finished in state Completed()
# 📥 Downloading dataset...
# Using Colab cache for faster access to the 'world-happiness' dataset.
# INFO:prefect.task_runs:Finished in state Completed()
# INFO:prefect.task_runs:Finished in state Completed()
# 🚀 Uploading 157 rows...
# INFO:prefect.task_runs:Finished in state Completed()
# INFO:prefect.flow_runs:Finished in state Completed()
# ✅ Check your Prefect Dashboard 'Runs' tab for 'World Happiness 2016 Pipeline'!
